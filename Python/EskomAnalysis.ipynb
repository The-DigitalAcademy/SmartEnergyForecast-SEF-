# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
eskom_fd =pd.read_csv("/Users/dslearner23/Downloads/myupdateddata.csv")
eskom_fd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Date Time Hour Beginning  \
# 0             0           0      2018-04-01 00:00:00
# 1             1           1      2018-04-01 01:00:00
# 2             2           2      2018-04-01 02:00:00
# 3             3           3      2018-04-01 03:00:00
# 4             4           4      2018-04-01 04:00:00
#
#    Original Res Forecast before Lockdown  Residual Forecast  \
# 0                                    0.0          19904.967
# 1                                    0.0          19553.899
# 2                                    0.0          19314.284
# 3                                    0.0          19342.679
# 4                                    0.0          19538.890
#
#    RSA Contracted Forecast  Dispatchable Generation  Residual Demand  \
# 0                20367.066                  20237.0          20237.0
# 1                19988.733                  19744.0          19744.0
# 2                19731.239                  19631.0          19631.0
# 3                19753.554                  19731.0          19731.0
# 4                19988.365                  19890.0          19890.0
#
#    RSA Contracted Demand  International Exports  ...  \
# 0              20722.058               1215.902  ...
# 1              20188.493               1203.474  ...
# 2              20019.603               1177.571  ...
# 3              20079.454               1184.312  ...
# 4              20237.490               1197.271  ...
#
#    Total RE Installed Capacity  Installed Eskom Capacity  Total PCLF  \
# 0                      3873.69                   44546.0    3987.472
# 1                      3873.69                   44546.0    3987.472
# 2                      3873.69                   44546.0    3987.472
# 3                      3873.69                   44546.0    3990.072
# 4                      3873.69                   44546.0    3990.472
#
#    Total UCLF  Total OCLF  Total UCLF+OCLF  Non Comm Sentout  \
# 0    8028.710     275.907           8304.0             617.0
# 1    7727.302     244.907           7972.0             209.0
# 2    7704.704     193.727           7898.0             431.0
# 3    7702.868     187.000           7889.0             868.0
# 4    7685.115     187.000           7872.0             115.0
#
#    Drakensberg Gen Unit Hours  Palmiet Gen Unit Hours  Ingula Gen Unit Hours
# 0                       383.0                    81.8                   36.9
# 1                       388.0                    83.0                   38.5
# 2                       388.0                    83.8                   40.3
# 3                       389.0                    85.0                   42.0
# 4                       385.0                    85.8                   43.7
#
# [5 rows x 44 columns]

# %%
eskom_fd
# Out:
#        Unnamed: 0.1  Unnamed: 0 Date Time Hour Beginning  \
# 0                 0           0      2018-04-01 00:00:00
# 1                 1           1      2018-04-01 01:00:00
# 2                 2           2      2018-04-01 02:00:00
# 3                 3           3      2018-04-01 03:00:00
# 4                 4           4      2018-04-01 04:00:00
# ...             ...         ...                      ...
# 43819         43819       43819      2023-03-31 19:00:00
# 43820         43820       43820      2023-03-31 20:00:00
# 43821         43821       43821      2023-03-31 21:00:00
# 43822         43822       43822      2023-03-31 22:00:00
# 43823         43823       43823      2023-03-31 23:00:00
#
#        Original Res Forecast before Lockdown  Residual Forecast  \
# 0                                        0.0          19904.967
# 1                                        0.0          19553.899
# 2                                        0.0          19314.284
# 3                                        0.0          19342.679
# 4                                        0.0          19538.890
# ...                                      ...                ...
# 43819                                    0.0          27746.667
# 43820                                    0.0          26101.656
# 43821                                    0.0          24646.570
# 43822                                    0.0          23384.907
# 43823                                    0.0          22313.206
#
#        RSA Contracted Forecast  Dispatchable Generation  Residual Demand  \
# 0                    20367.066             20237.000000     20237.000000
# 1                    19988.733             19744.000000     19744.000000
# 2                    19731.239             19631.000000     19631.000000
# 3                    19753.554             19731.000000     19731.000000
# 4                    19988.365             19890.000000     19890.000000
# ...                        ...                      ...              ...
# 43819                29314.632             24414.863393     24617.793193
# 43820                27605.215             24414.863393     24617.793193
# 43821                26030.785             24414.863393     24617.793193
# 43822                24597.115             24414.863393     24617.793193
# 43823                23446.158             24414.863393     24617.793193
#
#        RSA Contracted Demand  International Exports  ...  \
# 0               20722.058000            1215.902000  ...
# 1               20188.493000            1203.474000  ...
# 2               20019.603000            1177.571000  ...
# 3               20079.454000            1184.312000  ...
# 4               20237.490000            1197.271000  ...
# ...                      ...                    ...  ...
# 43819           26091.469545            1586.088402  ...
# 43820           26091.469545            1586.088402  ...
# 43821           26091.469545            1586.088402  ...
# 43822           26091.469545            1586.088402  ...
# 43823           26091.469545            1586.088402  ...
#
#        Total RE Installed Capacity  Installed Eskom Capacity   Total PCLF  \
# 0                      3873.690000              44546.000000  3987.472000
# 1                      3873.690000              44546.000000  3987.472000
# 2                      3873.690000              44546.000000  3987.472000
# 3                      3873.690000              44546.000000  3990.072000
# 4                      3873.690000              44546.000000  3990.472000
# ...                            ...                       ...          ...
# 43819                  4660.168154              45319.336728  4699.612693
# 43820                  4660.168154              45319.336728  4699.612693
# 43821                  4660.168154              45319.336728  4699.612693
# 43822                  4660.168154              45319.336728  4699.612693
# 43823                  4660.168154              45319.336728  4699.612693
#
#          Total UCLF  Total OCLF  Total UCLF+OCLF  Non Comm Sentout  \
# 0       8028.710000  275.907000      8304.000000        617.000000
# 1       7727.302000  244.907000      7972.000000        209.000000
# 2       7704.704000  193.727000      7898.000000        431.000000
# 3       7702.868000  187.000000      7889.000000        868.000000
# 4       7685.115000  187.000000      7872.000000        115.000000
# ...             ...         ...              ...               ...
# 43819  10094.312877  994.209083     11088.022836        455.353756
# 43820  10094.312877  994.209083     11088.022836        455.353756
# 43821  10094.312877  994.209083     11088.022836        455.353756
# 43822  10094.312877  994.209083     11088.022836        455.353756
# 43823  10094.312877  994.209083     11088.022836        455.353756
#
#        Drakensberg Gen Unit Hours  Palmiet Gen Unit Hours  \
# 0                      383.000000               81.800000
# 1                      388.000000               83.000000
# 2                      388.000000               83.800000
# 3                      389.000000               85.000000
# 4                      385.000000               85.800000
# ...                           ...                     ...
# 43819                  644.361216               82.698478
# 43820                  644.361216               82.698478
# 43821                  644.361216               82.698478
# 43822                  644.361216               82.698478
# 43823                  644.361216               82.698478
#
#        Ingula Gen Unit Hours
# 0                  36.900000
# 1                  38.500000
# 2                  40.300000
# 3                  42.000000
# 4                  43.700000
# ...                      ...
# 43819              42.852417
# 43820              42.852417
# 43821              42.852417
# 43822              42.852417
# 43823              42.852417
#
# [43824 rows x 44 columns]

# %%
eskom_fd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Date Time Hour Beginning  \
# 0             0           0      2018-04-01 00:00:00
# 1             1           1      2018-04-01 01:00:00
# 2             2           2      2018-04-01 02:00:00
# 3             3           3      2018-04-01 03:00:00
# 4             4           4      2018-04-01 04:00:00
#
#    Original Res Forecast before Lockdown  Residual Forecast  \
# 0                                    0.0          19904.967
# 1                                    0.0          19553.899
# 2                                    0.0          19314.284
# 3                                    0.0          19342.679
# 4                                    0.0          19538.890
#
#    RSA Contracted Forecast  Dispatchable Generation  Residual Demand  \
# 0                20367.066                  20237.0          20237.0
# 1                19988.733                  19744.0          19744.0
# 2                19731.239                  19631.0          19631.0
# 3                19753.554                  19731.0          19731.0
# 4                19988.365                  19890.0          19890.0
#
#    RSA Contracted Demand  International Exports  ...  \
# 0              20722.058               1215.902  ...
# 1              20188.493               1203.474  ...
# 2              20019.603               1177.571  ...
# 3              20079.454               1184.312  ...
# 4              20237.490               1197.271  ...
#
#    Total RE Installed Capacity  Installed Eskom Capacity  Total PCLF  \
# 0                      3873.69                   44546.0    3987.472
# 1                      3873.69                   44546.0    3987.472
# 2                      3873.69                   44546.0    3987.472
# 3                      3873.69                   44546.0    3990.072
# 4                      3873.69                   44546.0    3990.472
#
#    Total UCLF  Total OCLF  Total UCLF+OCLF  Non Comm Sentout  \
# 0    8028.710     275.907           8304.0             617.0
# 1    7727.302     244.907           7972.0             209.0
# 2    7704.704     193.727           7898.0             431.0
# 3    7702.868     187.000           7889.0             868.0
# 4    7685.115     187.000           7872.0             115.0
#
#    Drakensberg Gen Unit Hours  Palmiet Gen Unit Hours  Ingula Gen Unit Hours
# 0                       383.0                    81.8                   36.9
# 1                       388.0                    83.0                   38.5
# 2                       388.0                    83.8                   40.3
# 3                       389.0                    85.0                   42.0
# 4                       385.0                    85.8                   43.7
#
# [5 rows x 44 columns]

# %%
eskom_fd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Date Time Hour Beginning  \
# 0             0           0      2018-04-01 00:00:00
# 1             1           1      2018-04-01 01:00:00
# 2             2           2      2018-04-01 02:00:00
# 3             3           3      2018-04-01 03:00:00
# 4             4           4      2018-04-01 04:00:00
#
#    Original Res Forecast before Lockdown  Residual Forecast  \
# 0                                    0.0          19904.967
# 1                                    0.0          19553.899
# 2                                    0.0          19314.284
# 3                                    0.0          19342.679
# 4                                    0.0          19538.890
#
#    RSA Contracted Forecast  Dispatchable Generation  Residual Demand  \
# 0                20367.066                  20237.0          20237.0
# 1                19988.733                  19744.0          19744.0
# 2                19731.239                  19631.0          19631.0
# 3                19753.554                  19731.0          19731.0
# 4                19988.365                  19890.0          19890.0
#
#    RSA Contracted Demand  International Exports  ...  \
# 0              20722.058               1215.902  ...
# 1              20188.493               1203.474  ...
# 2              20019.603               1177.571  ...
# 3              20079.454               1184.312  ...
# 4              20237.490               1197.271  ...
#
#    Total RE Installed Capacity  Installed Eskom Capacity  Total PCLF  \
# 0                      3873.69                   44546.0    3987.472
# 1                      3873.69                   44546.0    3987.472
# 2                      3873.69                   44546.0    3987.472
# 3                      3873.69                   44546.0    3990.072
# 4                      3873.69                   44546.0    3990.472
#
#    Total UCLF  Total OCLF  Total UCLF+OCLF  Non Comm Sentout  \
# 0    8028.710     275.907           8304.0             617.0
# 1    7727.302     244.907           7972.0             209.0
# 2    7704.704     193.727           7898.0             431.0
# 3    7702.868     187.000           7889.0             868.0
# 4    7685.115     187.000           7872.0             115.0
#
#    Drakensberg Gen Unit Hours  Palmiet Gen Unit Hours  Ingula Gen Unit Hours
# 0                       383.0                    81.8                   36.9
# 1                       388.0                    83.0                   38.5
# 2                       388.0                    83.8                   40.3
# 3                       389.0                    85.0                   42.0
# 4                       385.0                    85.8                   43.7
#
# [5 rows x 44 columns]

# %%
eskom_fd['Timestamp'] = pd.to_datetime(eskom_fd['Date Time Hour Beginning'])

  #     0. Get units of time from the timestamp
eskom_fd['min'] = eskom_fd['Timestamp'].dt.minute
eskom_fd['hour'] =eskom_fd['Timestamp'].dt.hour
eskom_fd['wday'] = eskom_fd['Timestamp'].dt.dayofweek
eskom_fd['mday'] = eskom_fd['Timestamp'].dt.day
eskom_fd['yday'] = eskom_fd['Timestamp'].dt.dayofyear
eskom_fd['month'] = eskom_fd['Timestamp'].dt.month
eskom_fd['year'] = eskom_fd['Timestamp'].dt.year
eskom_fd['date'] =  eskom_fd['Timestamp'].dt.date
eskom_fd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Date Time Hour Beginning  \
# 0             0           0      2018-04-01 00:00:00
# 1             1           1      2018-04-01 01:00:00
# 2             2           2      2018-04-01 02:00:00
# 3             3           3      2018-04-01 03:00:00
# 4             4           4      2018-04-01 04:00:00
#
#    Original Res Forecast before Lockdown  Residual Forecast  \
# 0                                    0.0          19904.967
# 1                                    0.0          19553.899
# 2                                    0.0          19314.284
# 3                                    0.0          19342.679
# 4                                    0.0          19538.890
#
#    RSA Contracted Forecast  Dispatchable Generation  Residual Demand  \
# 0                20367.066                  20237.0          20237.0
# 1                19988.733                  19744.0          19744.0
# 2                19731.239                  19631.0          19631.0
# 3                19753.554                  19731.0          19731.0
# 4                19988.365                  19890.0          19890.0
#
#    RSA Contracted Demand  International Exports  ...  Ingula Gen Unit Hours  \
# 0              20722.058               1215.902  ...                   36.9
# 1              20188.493               1203.474  ...                   38.5
# 2              20019.603               1177.571  ...                   40.3
# 3              20079.454               1184.312  ...                   42.0
# 4              20237.490               1197.271  ...                   43.7
#
#             Timestamp  min  hour  wday  mday  yday  month  year        date
# 0 2018-04-01 00:00:00    0     0     6     1    91      4  2018  2018-04-01
# 1 2018-04-01 01:00:00    0     1     6     1    91      4  2018  2018-04-01
# 2 2018-04-01 02:00:00    0     2     6     1    91      4  2018  2018-04-01
# 3 2018-04-01 03:00:00    0     3     6     1    91      4  2018  2018-04-01
# 4 2018-04-01 04:00:00    0     4     6     1    91      4  2018  2018-04-01
#
# [5 rows x 53 columns]

# %%
eskom_fd.drop(["Unnamed: 0.1","Unnamed: 0","Date Time Hour Beginning","Timestamp","Original Res Forecast before Lockdown","date"],axis=1)
eskom_fd.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Date Time Hour Beginning  \
# 0             0           0      2018-04-01 00:00:00
# 1             1           1      2018-04-01 01:00:00
# 2             2           2      2018-04-01 02:00:00
# 3             3           3      2018-04-01 03:00:00
# 4             4           4      2018-04-01 04:00:00
#
#    Original Res Forecast before Lockdown  Residual Forecast  \
# 0                                    0.0          19904.967
# 1                                    0.0          19553.899
# 2                                    0.0          19314.284
# 3                                    0.0          19342.679
# 4                                    0.0          19538.890
#
#    RSA Contracted Forecast  Dispatchable Generation  Residual Demand  \
# 0                20367.066                  20237.0          20237.0
# 1                19988.733                  19744.0          19744.0
# 2                19731.239                  19631.0          19631.0
# 3                19753.554                  19731.0          19731.0
# 4                19988.365                  19890.0          19890.0
#
#    RSA Contracted Demand  International Exports  ...  Ingula Gen Unit Hours  \
# 0              20722.058               1215.902  ...                   36.9
# 1              20188.493               1203.474  ...                   38.5
# 2              20019.603               1177.571  ...                   40.3
# 3              20079.454               1184.312  ...                   42.0
# 4              20237.490               1197.271  ...                   43.7
#
#             Timestamp  min  hour  wday  mday  yday  month  year        date
# 0 2018-04-01 00:00:00    0     0     6     1    91      4  2018  2018-04-01
# 1 2018-04-01 01:00:00    0     1     6     1    91      4  2018  2018-04-01
# 2 2018-04-01 02:00:00    0     2     6     1    91      4  2018  2018-04-01
# 3 2018-04-01 03:00:00    0     3     6     1    91      4  2018  2018-04-01
# 4 2018-04-01 04:00:00    0     4     6     1    91      4  2018  2018-04-01
#
# [5 rows x 53 columns]

# %%
eskom_fd.shape
# Out:
# (43824, 53)

# %%
#chech for null values
eskom_fd.isnull().sum()
# Out:
# Unnamed: 0.1                             0
# Unnamed: 0                               0
# Date Time Hour Beginning                 0
# Original Res Forecast before Lockdown    0
# Residual Forecast                        0
# RSA Contracted Forecast                  0
# Dispatchable Generation                  0
# Residual Demand                          0
# RSA Contracted Demand                    0
# International Exports                    0
# International Imports                    0
# Thermal Generation                       0
# Nuclear Generation                       0
# Eskom Gas Generation                     0
# Eskom OCGT Generation                    0
# Hydro Water Generation                   0
# Pumped Water Generation                  0
# ILS Usage                                0
# Manual Load_Reduction(MLR)               0
# IOS Excl ILS and MLR                     0
# Dispatchable IPP OCGT                    0
# Eskom Gas SCO                            0
# Eskom OCGT SCO                           0
# Hydro Water SCO                          0
# Pumped Water SCO Pumping                 0
# Wind                                     0
# PV                                       0
# CSP                                      0
# Other RE                                 0
# Total RE                                 0
# Wind Installed Capacity                  0
# PV Installed Capacity                    0
# CSP Installed Capacity                   0
# Other RE Installed Capacity              0
# Total RE Installed Capacity              0
# Installed Eskom Capacity                 0
# Total PCLF                               0
# Total UCLF                               0
# Total OCLF                               0
# Total UCLF+OCLF                          0
# Non Comm Sentout                         0
# Drakensberg Gen Unit Hours               0
# Palmiet Gen Unit Hours                   0
# Ingula Gen Unit Hours                    0
# Timestamp                                0
# min                                      0
# hour                                     0
# wday                                     0
# mday                                     0
# yday                                     0
# month                                    0
# year                                     0
# date                                     0
# dtype: int64

# %%
eskom_fd.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Date Time Hour Beginning',
#        'Original Res Forecast before Lockdown', 'Residual Forecast',
#        'RSA Contracted Forecast', 'Dispatchable Generation', 'Residual Demand',
#        'RSA Contracted Demand', 'International Exports',
#        'International Imports', 'Thermal Generation', 'Nuclear Generation',
#        'Eskom Gas Generation', 'Eskom OCGT Generation',
#        'Hydro Water Generation', 'Pumped Water Generation', 'ILS Usage',
#        'Manual Load_Reduction(MLR)', 'IOS Excl ILS and MLR',
#        'Dispatchable IPP OCGT', 'Eskom Gas SCO', 'Eskom OCGT SCO',
#        'Hydro Water SCO', 'Pumped Water SCO Pumping', 'Wind', 'PV', 'CSP',
#        'Other RE', 'Total RE', 'Wind Installed Capacity',
#        'PV Installed Capacity', 'CSP Installed Capacity',
#        'Other RE Installed Capacity', 'Total RE Installed Capacity',
#        'Installed Eskom Capacity', 'Total PCLF', 'Total UCLF', 'Total OCLF',
#        'Total UCLF+OCLF', 'Non Comm Sentout', 'Drakensberg Gen Unit Hours',
#        'Palmiet Gen Unit Hours', 'Ingula Gen Unit Hours', 'Timestamp', 'min',
#        'hour', 'wday', 'mday', 'yday', 'month', 'year', 'date'],
#       dtype='object')

# %%
ass=eskom_fd[['Timestamp', 'min','hour']]
ass.head()
# Out:
#             Timestamp  min  hour
# 0 2018-04-01 00:00:00    0     0
# 1 2018-04-01 01:00:00    0     1
# 2 2018-04-01 02:00:00    0     2
# 3 2018-04-01 03:00:00    0     3
# 4 2018-04-01 04:00:00    0     4

# %%
data =eskom_fd[['Hydro Water SCO', 'Pumped Water SCO Pumping', 'Wind', 'PV', 'CSP',
       'Other RE', 'Total RE']]
data.head()
# Out:
#    Hydro Water SCO  Pumped Water SCO Pumping     Wind   PV     CSP  Other RE  \
# 0              0.0                   -1614.0  454.964  0.0  17.555    12.539
# 1              0.0                   -1945.0  392.958  0.0  39.131    12.404
# 2              0.0                   -1938.0  337.358  0.0  39.163    12.082
# 3              0.0                   -1952.0  297.234  0.0  38.942    12.278
# 4              0.0                   -1873.0  309.978  0.0  25.024    12.488
#
#    Total RE
# 0   485.058
# 1   444.493
# 2   388.603
# 3   348.454
# 4   347.490

# %% [markdown]
# MAP NUMERICAL MONTHS TO MONTH NAMES

# %%
# Map numeric months to month names
month_dict = {1:'January', 2:'February', 3:'March', 4:'April', 5:'May', 6:'June', 
              7:'July', 8:'August', 9:'September', 10:'October', 11:'November', 12:'December'}
eskom_fd['month'] = eskom_fd['month'].map(month_dict)

# %% [markdown]
# THE HOURLY AVERAGE DEMAND THAT NEEDS TO BE SUPPLIED BY ALL RESOURCES THAT CAN BE DISPATCHED BY ESKOM NATIONAL CONTROL.

# %%
fig = plt.figure(figsize=(30,10))
# Create a bar plot using Seaborn
sns.lineplot(x='hour', y='Residual Demand',data=eskom_fd)


# Set the plot title and axis labels
plt.title('Hourly Residual Demand')
plt.xlabel('hour')
plt.ylabel('Total Demand MW')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# ENERGY THAT IS EXPORTED FROM RSA TO NEIGHBORING COUNTRIES VS ENERGY THAT IS IMPORTED INTO RSA FROM NEIGHBORING COUNTRIES.

# %%
# Reshape the data into a long format
df_long = pd.melt(eskom_fd, id_vars=['year'], value_vars=['International Exports', 'International Imports'], 
                  var_name='Labels', value_name='total')
fig = plt.figure(figsize=(30,10))

# Create a bar plot using Seaborn
sns.lineplot(x='year', y='total', hue='Labels', data=df_long)

# Set the plot title and axis labels
plt.title('Exported Energy vs Imported Energy')
plt.xlabel('Year')
plt.ylabel('Total Energy (Gwh)')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# HOW DOES POWER THEFT AFFECT DEMAND

# %%
# Reshape the data into a long format
df_long = pd.melt(eskom_fd, id_vars=['month'], value_vars=['Total UCLF', 'Total PCLF', 'Total OCLF'], 
                  var_name='Power Cuts', value_name='total')
fig = plt.figure(figsize=(30,10))

# Create a bar plot using Seaborn
sns.barplot(x='month', y='total', hue='Power Cuts', data=df_long)

# Set the plot title and axis labels

plt.title('Monthly Planned/Unplanned Power Cuts')
plt.xlabel('Year')
plt.ylabel('Total Power cuts')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# THE AMOUNT OF ENERGY GENERATED BY EACH STATION PER MONTH

# %%
df_long = pd.melt(eskom_fd, id_vars=['month'], value_vars=['Drakensberg Gen Unit Hours', 'Palmiet Gen Unit Hours', 'Ingula Gen Unit Hours'], 
                  var_name='Power Stations', value_name='total')

fig = plt.figure(figsize=(30,10))

# Create a bar plot using Seaborn
sns.lineplot(x='month', y='total', hue='Power Stations', data=df_long)

# Add a title
plt.title('Monthly Power Generated Per Station')
plt.ylabel('Total Power Generated')
plt.xlabel('Month')

# Show the plot
plt.show()

# %% [markdown]
# THE DISTRIBUTION OF POWER SOURCES

# %%
fig = plt.figure(figsize=(30,10))
# Reshape the data into a long format
df_long = pd.melt(eskom_fd, id_vars=['year'], value_vars=['Wind', 'PV', 'CSP', 'Other RE'], 
                  var_name='Power Sources', value_name='total')



# Calculate the total capacity for each power source
df_pie = df_long.groupby(['Power Sources'])['total'].sum().reset_index()

# Create a pie chart with colors
plt.pie(df_pie['total'], labels=df_pie['Power Sources'], autopct='%1.1f%%')


# Add a title
plt.title('Distribution of Power Sources')

# Show the plot
plt.show()

# %% [markdown]
# THE AMOUNT AND TYPE OF ENERGY GENERATED BY ESKOM FROM 2018 - 2023

# %%
# Reshape the data into a long format
df_long = pd.melt(eskom_fd, id_vars=['year'], value_vars=['Thermal Generation','Dispatchable Generation',
       'Nuclear Generation', 'Eskom Gas Generation', 'Eskom OCGT Generation',
       'Hydro Water Generation', 'Pumped Water Generation'], 
                  var_name='Energy Generated', value_name='Total of Generated Energy')

fig = plt.figure(figsize=(30,10))

# Create a bar plot using Seaborn
sns.lineplot(x='year', y='Total of Generated Energy', hue='Energy Generated', data=df_long)

# Set the plot title and axis labels
plt.title('Energy Generated from 2018 to 2023')
plt.xlabel('Year')
plt.ylabel('Total of Generated Energy')


# Show the plot
plt.show()

# %% [markdown]
# EXTRACT TIME FROM TIMESTAMP

# %%
import datetime as dt
# Define the format to be used. format1 is the format from to_datetime while format2 is the new output format
format1 ="%m/%d/%Y %I:%M:%S %p"
format2 = "%H:%M:%S"

# Convert and store datetime in new format
eskom_fd['Time']= pd.to_datetime(eskom_fd['Timestamp'], format=format1).dt.strftime(format2)

# %% [markdown]
# WIND, POWER IS STABLE THROUGHOUT THE DAY AND IS THE HIGHEST IN SUMMER MONTHS. PV IS ONLY AVAILABLE WHEN THE SUN IS OUT, NORMALLY from 6:00 to 18:00.

# %%
fig = plt.figure(figsize=(30,10))
# Create a bar plot using Seaborn
sns.barplot(x='Time', y='PV', data=eskom_fd)

# Set the plot title and axis labels

plt.title('Hourly Total Contracted PV Generated ')
plt.xlabel('Time')
plt.ylabel('Total Contracted PV Generated')
plt.xticks(rotation=45)

# Show the plot
plt.show()
